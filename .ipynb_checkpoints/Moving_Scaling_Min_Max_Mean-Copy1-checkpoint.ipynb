# %% [markdown]
# ## This is basically a duplicate for the other moving scale notebook, and the special thing about it is that it uses three different lstm for estimation of min, max and mean. However, quite weiredly, in the end, the three curves are basically a shift of each other. The fact that they converged to the same thing is quite amazing.

# %% [markdown]
# ### Loading packages

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential, Model, load_model
from keras.layers import Dense
from keras.layers import LSTM, GRU, Conv1D, MaxPooling1D, Flatten, TimeDistributed, Concatenate
from keras.layers import GaussianNoise, BatchNormalization, Dropout
from keras.layers import Activation, merge, Input, concatenate, Reshape, add
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.callbacks import Callback, LambdaCallback, TensorBoard, ReduceLROnPlateau, EarlyStopping, LearningRateScheduler
from keras.utils import np_utils, to_categorical
from keras.utils.vis_utils import plot_model 
import tensorflow as tf
import keras.backend as K
import matplotlib.pyplot as plt
import time
# %matplotlib inline
# Out:
# /home/yuze/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Function that is used to normalize the data to a fixed mean and std of data

# %%
def moving_normalize(df, mean_window_size=520, future_window_size=40):
    """
    Due to the fact that index is constantly growing, using a universal normalizing method is infeasible.
    The function use mean_window_size to calculate mean, and use the mean to divide future_window_size data.
    """
    out = df.copy()
    
    for i in range(mean_window_size, len(df)-future_window_size, future_window_size):
        out.iloc[i:i+future_window_size, :] = df.iloc[i:i+future_window_size, :] / df.iloc[i-mean_window_size:i, :].mean()
    
    i = i-future_window_size
    if not i == len(df)-future_window_size-1:
        out.iloc[i:, :] = df.iloc[i:, :] / df.iloc[i-mean_window_size:i, :].mean()
    
    return out.iloc[mean_window_size:, :] - 1

# %% [markdown]
# ### Function that generate train data for the training and testing of the neural network

# %%
def generate_train_data(df, test_split=0.2, valid_split=0.1, input_len=20, output_len=10):
    """
    input is a sequence of length input_len
    output is a single value mean of length output_len
    """
    out = {}
    
    data_len = len(df)-output_len
    test_split_len = int(data_len*(1-test_split-valid_split))
    valid_split_len = int(data_len*(1-valid_split))
    
    out["train_input"] = np.array([df.iloc[i-input_len:i, :].values for i in range(input_len, test_split_len)])
    out["train_output_max"] = np.array([df.iloc[i:i+output_len, 1].max() for i in range(input_len, test_split_len)])
    out["train_output_min"] = np.array([df.iloc[i:i+output_len, 2].min() for i in range(input_len, test_split_len)])
    out["train_output_mean"] = np.array([df.iloc[i:i+output_len, [0, 3]].mean(axis=1).mean() for i in range(input_len, test_split_len)])
    out["test_input"] = np.array([df.iloc[i-input_len:i, :].values for i in range(test_split_len, valid_split_len)])
    out["test_output_max"] = np.array([df.iloc[i:i+output_len, 1].max() for i in range(test_split_len, valid_split_len)])
    out["test_output_min"] = np.array([df.iloc[i:i+output_len, 2].min() for i in range(test_split_len, valid_split_len)])
    out["test_output_mean"] = np.array([df.iloc[i:i+output_len, [0, 3]].mean(axis=1).mean() for i in range(test_split_len, valid_split_len)])
    out["valid_input"] = np.array([df.iloc[i-input_len:i, :].values for i in range(valid_split_len, data_len)])
    out["valid_output_max"] = np.array([df.iloc[i:i+output_len, 1].max() for i in range(valid_split_len, data_len)])
    out["valid_output_min"] = np.array([df.iloc[i:i+output_len, 2].min() for i in range(valid_split_len, data_len)])
    out["valid_output_mean"] = np.array([df.iloc[i:i+output_len, [0, 3]].mean(axis=1).mean() for i in range(valid_split_len, data_len)])
    
    return out

# %% [markdown]
# ### Decide how long a sequence to be fed into the neural network, and how long into the future the model is to predict

# %%
# input and output length
input_len = 200
output_len = 10

# %% [markdown]
# ### Load S&P history data and prepare train data based on it

# %%
# read the factor time data
df = pd.read_csv("^GSPC.csv", index_col=[0], parse_dates=[0]).iloc[1:, :-1]

# normalize data
# target = augment_moving_normalize(df, 520 ,seq_len)
normalized_df = moving_normalize(df, mean_window_size=260, future_window_size=1)
output_df = normalized_df.iloc[:, [1, 2]]
input_df = normalized_df.iloc[:, [0, 1, 2, 3]]

# create train data
train_data = generate_train_data(input_df, test_split=0.2, valid_split=0.1, input_len=input_len, output_len=output_len)

# %% [markdown]
# ### Create the structure of the neural network

# %% [markdown]
# ### Structure that has min max mean at same level

# %%
# flow for prev_label_input
seq_input = Input(shape=(input_len, 4), name="sequence_input")

lstm_feature = LSTM(units=128, activation="relu", kernel_regularizer=l2(l=0.01), return_sequences=False, name="lstm_layer")(seq_input)
common_feature = Dense(units=64, activation="relu", name="common_feature")(lstm_feature)

x = Dense(units=64, activation="relu", name="max_feature")(lstm_feature)
x = Concatenate(name="combined_max_feature")([x, common_feature])
x = Dropout(rate=0.5)(x)
output_max = Dense(units=1, activation="tanh", name="max_output")(x)

x = Dense(units=64, activation="relu", name="min_feature")(lstm_feature)
x = Concatenate(name="combined_min_feature")([x, common_feature])
x = Dropout(rate=0.5)(x)
output_min = Dense(units=1, activation="tanh", name="min_output")(x)

x = Dense(units=64, activation="relu", name="mean_feature")(lstm_feature)
x = Concatenate(name="combined_mean_feature")([x, common_feature])
x = Dropout(rate=0.5)(x)
output_mean = Dense(units=1, activation="tanh", name="mean_output")(x)

# compile model
Indexer = Model(inputs=[seq_input], outputs=[output_max, output_min, output_mean])
Indexer.compile(loss="mse", optimizer=Adam(lr=0.005), metrics=["mse"])

# display model
plot_model(model=Indexer, to_file="indexer_stucture.png")
Indexer.summary()
# Out:
# WARNING:tensorflow:From /home/yuze/anaconda3/envs/tensorflow/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:1247: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/yuze/anaconda3/envs/tensorflow/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:1349: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sequence_input (InputLayer)     (None, 200, 4)       0
# __________________________________________________________________________________________________
# lstm_layer (LSTM)               (None, 128)          68096       sequence_input[0][0]
# __________________________________________________________________________________________________
# max_feature (Dense)             (None, 64)           8256        lstm_layer[0][0]
# __________________________________________________________________________________________________
# common_feature (Dense)          (None, 64)           8256        lstm_layer[0][0]
# __________________________________________________________________________________________________
# min_feature (Dense)             (None, 64)           8256        lstm_layer[0][0]
# __________________________________________________________________________________________________
# mean_feature (Dense)            (None, 64)           8256        lstm_layer[0][0]
# __________________________________________________________________________________________________
# combined_max_feature (Concatena (None, 128)          0           max_feature[0][0]
#                                                                  common_feature[0][0]
# __________________________________________________________________________________________________
# combined_min_feature (Concatena (None, 128)          0           min_feature[0][0]
#                                                                  common_feature[0][0]
# __________________________________________________________________________________________________
# combined_mean_feature (Concaten (None, 128)          0           mean_feature[0][0]
#                                                                  common_feature[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           combined_max_feature[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           combined_min_feature[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128)          0           combined_mean_feature[0][0]
# __________________________________________________________________________________________________
# max_output (Dense)              (None, 1)            129         dropout_1[0][0]
# __________________________________________________________________________________________________
# min_output (Dense)              (None, 1)            129         dropout_2[0][0]
# __________________________________________________________________________________________________
# mean_output (Dense)             (None, 1)            129         dropout_3[0][0]
# ==================================================================================================
# Total params: 101,507
# Trainable params: 101,507
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# flow for prev_label_input
seq_input = Input(shape=(input_len, 4), name="sequence_input")

lstm_feature_max = LSTM(units=64, activation="relu", kernel_regularizer=l2(l=0.01), return_sequences=False, name="lstm_layer_max")(seq_input)
lstm_feature_min = LSTM(units=128, activation="relu", kernel_regularizer=l2(l=0.01), return_sequences=False, name="lstm_layer_min")(seq_input)
lstm_feature_mean = LSTM(units=64, activation="relu", kernel_regularizer=l2(l=0.01), return_sequences=False, name="lstm_layer_mean")(seq_input)

x = Dense(units=64, activation="relu", name="max_feature")(lstm_feature_max)
x = Dropout(rate=0.5)(x)
output_max = Dense(units=1, activation="tanh", name="max_output")(x)

x = Dense(units=64, activation="relu", name="min_feature")(lstm_feature_min)
x = Dropout(rate=0.5)(x)
output_min = Dense(units=1, activation="tanh", name="min_output")(x)

x = Dense(units=64, activation="relu", name="mean_feature")(lstm_feature_mean)
x = Dropout(rate=0.5)(x)
output_mean = Dense(units=1, activation="tanh", name="mean_output")(x)

# compile model
Indexer = Model(inputs=[seq_input], outputs=[output_max, output_min, output_mean])
Indexer.compile(loss="mse", optimizer=Adam(lr=0.005), metrics=["mse"])

# display model
plot_model(model=Indexer, to_file="indexer_stucture.png")
Indexer.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sequence_input (InputLayer)     (None, 200, 4)       0
# __________________________________________________________________________________________________
# lstm_layer_max (LSTM)           (None, 64)           17664       sequence_input[0][0]
# __________________________________________________________________________________________________
# lstm_layer_min (LSTM)           (None, 128)          68096       sequence_input[0][0]
# __________________________________________________________________________________________________
# lstm_layer_mean (LSTM)          (None, 64)           17664       sequence_input[0][0]
# __________________________________________________________________________________________________
# max_feature (Dense)             (None, 64)           4160        lstm_layer_max[0][0]
# __________________________________________________________________________________________________
# min_feature (Dense)             (None, 64)           8256        lstm_layer_min[0][0]
# __________________________________________________________________________________________________
# mean_feature (Dense)            (None, 64)           4160        lstm_layer_mean[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 64)           0           max_feature[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 64)           0           min_feature[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 64)           0           mean_feature[0][0]
# __________________________________________________________________________________________________
# max_output (Dense)              (None, 1)            65          dropout_10[0][0]
# __________________________________________________________________________________________________
# min_output (Dense)              (None, 1)            65          dropout_11[0][0]
# __________________________________________________________________________________________________
# mean_output (Dense)             (None, 1)            65          dropout_12[0][0]
# ==================================================================================================
# Total params: 120,195
# Trainable params: 120,195
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Start the training of the neural network

# %%
log = Indexer.fit(x=train_data["train_input"], y=[train_data['train_output_max'], train_data['train_output_min'], train_data['train_output_mean']], 
            validation_data=[train_data["test_input"], [train_data["test_output_max"], train_data["test_output_min"], train_data['test_output_mean']]],
            epochs=60, batch_size=256, shuffle=True, verbose=1)
# Out:
# Train on 11725 samples, validate on 3408 samples
# Epoch 1/60
-04 - min_output_loss: 0.0011 - mean_output_loss: 8.5028e-04 - max_output_mean_squared_error: 8.1135e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 8.5028e-04 - val_loss: 0.0032 - val_max_output_loss: 6.0714e-04 - val_min_output_loss: 0.0018 - val_mean_output_loss: 5.5779e-04 - val_max_output_mean_squared_error: 6.0714e-04 - val_min_output_mean_squared_error: 0.0018 - val_mean_output_mean_squared_error: 5.5779e-04
# Epoch 16/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0031 - max_output_loss: 8.1250e-04 - min_output_loss: 0.0011 - mean_output_loss: 8.1494e-04 - max_output_mean_squared_error: 8.1250e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 8.1494e-04 - val_loss: 0.0026 - val_max_output_loss: 5.4222e-04 - val_min_output_loss: 0.0011 - val_mean_output_loss: 6.5307e-04 - val_max_output_mean_squared_error: 5.4222e-04 - val_min_output_mean_squared_error: 0.0011 - val_mean_output_mean_squared_error: 6.5307e-04
# Epoch 17/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0030 - max_output_loss: 8.2914e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.5278e-04 - max_output_mean_squared_error: 8.2914e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.5278e-04 - val_loss: 0.0025 - val_max_output_loss: 5.1594e-04 - val_min_output_loss: 0.0011 - val_mean_output_loss: 6.4807e-04 - val_max_output_mean_squared_error: 5.1594e-04 - val_min_output_mean_squared_error: 0.0011 - val_mean_output_mean_squared_error: 6.4807e-04
# Epoch 18/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0030 - max_output_loss: 8.7025e-04 - min_output_loss: 0.0011 - mean_output_loss: 8.2158e-04 - max_output_mean_squared_error: 8.7025e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 8.2158e-04 - val_loss: 0.0032 - val_max_output_loss: 8.1986e-04 - val_min_output_loss: 0.0014 - val_mean_output_loss: 7.5377e-04 - val_max_output_mean_squared_error: 8.1986e-04 - val_min_output_mean_squared_error: 0.0014 - val_mean_output_mean_squared_error: 7.5377e-04
# Epoch 19/60
# 11725/11725 [==============================] - 18s 1ms/step - loss: 0.0029 - max_output_loss: 8.3917e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.7833e-04 - max_output_mean_squared_error: 8.3917e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.7833e-04 - val_loss: 0.0028 - val_max_output_loss: 5.1928e-04 - val_min_output_loss: 0.0014 - val_mean_output_loss: 6.8675e-04 - val_max_output_mean_squared_error: 5.1928e-04 - val_min_output_mean_squared_error: 0.0014 - val_mean_output_mean_squared_error: 6.8675e-04
# Epoch 20/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0029 - max_output_loss: 8.0603e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.7719e-04 - max_output_mean_squared_error: 8.0603e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.7719e-04 - val_loss: 0.0025 - val_max_output_loss: 5.4441e-04 - val_min_output_loss: 0.0010 - val_mean_output_loss: 6.5707e-04 - val_max_output_mean_squared_error: 5.4441e-04 - val_min_output_mean_squared_error: 0.0010 - val_mean_output_mean_squared_error: 6.5707e-04
# Epoch 21/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0029 - max_output_loss: 8.3919e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.7336e-04 - max_output_mean_squared_error: 8.3919e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.7336e-04 - val_loss: 0.0027 - val_max_output_loss: 5.0718e-04 - val_min_output_loss: 0.0013 - val_mean_output_loss: 7.3215e-04 - val_max_output_mean_squared_error: 5.0718e-04 - val_min_output_mean_squared_error: 0.0013 - val_mean_output_mean_squared_error: 7.3215e-04
# Epoch 22/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0029 - max_output_loss: 8.4994e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.7243e-04 - max_output_mean_squared_error: 8.4994e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.7243e-04 - val_loss: 0.0026 - val_max_output_loss: 6.2007e-04 - val_min_output_loss: 0.0011 - val_mean_output_loss: 5.8492e-04 - val_max_output_mean_squared_error: 6.2007e-04 - val_min_output_mean_squared_error: 0.0011 - val_mean_output_mean_squared_error: 5.8492e-04
# Epoch 23/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 7.8376e-04 - min_output_loss: 0.0010 - mean_output_loss: 7.4204e-04 - max_output_mean_squared_error: 7.8376e-04 - min_output_mean_squared_error: 0.0010 - mean_output_mean_squared_error: 7.4204e-04 - val_loss: 0.0026 - val_max_output_loss: 4.5519e-04 - val_min_output_loss: 0.0014 - val_mean_output_loss: 5.3048e-04 - val_max_output_mean_squared_error: 4.5519e-04 - val_min_output_mean_squared_error: 0.0014 - val_mean_output_mean_squared_error: 5.3048e-04
# Epoch 24/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0029 - max_output_loss: 7.8554e-04 - min_output_loss: 0.0011 - mean_output_loss: 8.3062e-04 - max_output_mean_squared_error: 7.8554e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 8.3062e-04 - val_loss: 0.0024 - val_max_output_loss: 5.7215e-04 - val_min_output_loss: 0.0010 - val_mean_output_loss: 5.3621e-04 - val_max_output_mean_squared_error: 5.7215e-04 - val_min_output_mean_squared_error: 0.0010 - val_mean_output_mean_squared_error: 5.3621e-04
# Epoch 25/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0029 - max_output_loss: 8.5301e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.7923e-04 - max_output_mean_squared_error: 8.5301e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.7923e-04 - val_loss: 0.0032 - val_max_output_loss: 5.9676e-04 - val_min_output_loss: 0.0018 - val_mean_output_loss: 6.4131e-04 - val_max_output_mean_squared_error: 5.9676e-04 - val_min_output_mean_squared_error: 0.0018 - val_mean_output_mean_squared_error: 6.4131e-04
# Epoch 26/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0029 - max_output_loss: 7.7696e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.8204e-04 - max_output_mean_squared_error: 7.7696e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.8204e-04 - val_loss: 0.0025 - val_max_output_loss: 4.6509e-04 - val_min_output_loss: 0.0010 - val_mean_output_loss: 8.1048e-04 - val_max_output_mean_squared_error: 4.6509e-04 - val_min_output_mean_squared_error: 0.0010 - val_mean_output_mean_squared_error: 8.1048e-04
# Epoch 27/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0029 - max_output_loss: 8.4901e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.5255e-04 - max_output_mean_squared_error: 8.4901e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.5255e-04 - val_loss: 0.0024 - val_max_output_loss: 5.3364e-04 - val_min_output_loss: 0.0011 - val_mean_output_loss: 5.3193e-04 - val_max_output_mean_squared_error: 5.3364e-04 - val_min_output_mean_squared_error: 0.0011 - val_mean_output_mean_squared_error: 5.3193e-04
# Epoch 28/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0029 - max_output_loss: 8.5015e-04 - min_output_loss: 0.0010 - mean_output_loss: 7.5216e-04 - max_output_mean_squared_error: 8.5015e-04 - min_output_mean_squared_error: 0.0010 - mean_output_mean_squared_error: 7.5216e-04 - val_loss: 0.0030 - val_max_output_loss: 6.1136e-04 - val_min_output_loss: 0.0015 - val_mean_output_loss: 6.6916e-04 - val_max_output_mean_squared_error: 6.1136e-04 - val_min_output_mean_squared_error: 0.0015 - val_mean_output_mean_squared_error: 6.6916e-04
# Epoch 29/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 8.1108e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.6883e-04 - max_output_mean_squared_error: 8.1108e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.6883e-04 - val_loss: 0.0024 - val_max_output_loss: 5.8458e-04 - val_min_output_loss: 0.0010 - val_mean_output_loss: 6.0319e-04 - val_max_output_mean_squared_error: 5.8458e-04 - val_min_output_mean_squared_error: 0.0010 - val_mean_output_mean_squared_error: 6.0319e-04
# Epoch 30/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0029 - max_output_loss: 8.0956e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.8121e-04 - max_output_mean_squared_error: 8.0956e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.8121e-04 - val_loss: 0.0026 - val_max_output_loss: 6.7262e-04 - val_min_output_loss: 0.0011 - val_mean_output_loss: 5.4888e-04 - val_max_output_mean_squared_error: 6.7262e-04 - val_min_output_mean_squared_error: 0.0011 - val_mean_output_mean_squared_error: 5.4888e-04
# Epoch 31/60
# 11725/11725 [==============================] - 18s 1ms/step - loss: 0.0028 - max_output_loss: 7.9978e-04 - min_output_loss: 0.0010 - mean_output_loss: 7.6119e-04 - max_output_mean_squared_error: 7.9978e-04 - min_output_mean_squared_error: 0.0010 - mean_output_mean_squared_error: 7.6119e-04 - val_loss: 0.0029 - val_max_output_loss: 4.8083e-04 - val_min_output_loss: 0.0012 - val_mean_output_loss: 9.4232e-04 - val_max_output_mean_squared_error: 4.8083e-04 - val_min_output_mean_squared_error: 0.0012 - val_mean_output_mean_squared_error: 9.4232e-04
# Epoch 32/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 7.4790e-04 - min_output_loss: 0.0011 - mean_output_loss: 8.0743e-04 - max_output_mean_squared_error: 7.4790e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 8.0743e-04 - val_loss: 0.0028 - val_max_output_loss: 5.2523e-04 - val_min_output_loss: 0.0014 - val_mean_output_loss: 6.7928e-04 - val_max_output_mean_squared_error: 5.2523e-04 - val_min_output_mean_squared_error: 0.0014 - val_mean_output_mean_squared_error: 6.7928e-04
# Epoch 33/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 7.7027e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.0755e-04 - max_output_mean_squared_error: 7.7027e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.0755e-04 - val_loss: 0.0028 - val_max_output_loss: 7.6455e-04 - val_min_output_loss: 0.0012 - val_mean_output_loss: 6.0992e-04 - val_max_output_mean_squared_error: 7.6455e-04 - val_min_output_mean_squared_error: 0.0012 - val_mean_output_mean_squared_error: 6.0992e-04
# Epoch 34/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 7.9389e-04 - min_output_loss: 0.0010 - mean_output_loss: 7.8502e-04 - max_output_mean_squared_error: 7.9389e-04 - min_output_mean_squared_error: 0.0010 - mean_output_mean_squared_error: 7.8502e-04 - val_loss: 0.0021 - val_max_output_loss: 4.5769e-04 - val_min_output_loss: 9.4358e-04 - val_mean_output_loss: 5.2724e-04 - val_max_output_mean_squared_error: 4.5769e-04 - val_min_output_mean_squared_error: 9.4358e-04 - val_mean_output_mean_squared_error: 5.2724e-04
# Epoch 35/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 7.7976e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.3013e-04 - max_output_mean_squared_error: 7.7976e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.3013e-04 - val_loss: 0.0025 - val_max_output_loss: 4.2035e-04 - val_min_output_loss: 0.0012 - val_mean_output_loss: 7.0219e-04 - val_max_output_mean_squared_error: 4.2035e-04 - val_min_output_mean_squared_error: 0.0012 - val_mean_output_mean_squared_error: 7.0219e-04
# Epoch 36/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 7.8121e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.2601e-04 - max_output_mean_squared_error: 7.8121e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.2601e-04 - val_loss: 0.0022 - val_max_output_loss: 5.5218e-04 - val_min_output_loss: 9.5338e-04 - val_mean_output_loss: 5.3384e-04 - val_max_output_mean_squared_error: 5.5218e-04 - val_min_output_mean_squared_error: 9.5338e-04 - val_mean_output_mean_squared_error: 5.3384e-04
# Epoch 37/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 8.0588e-04 - min_output_loss: 0.0010 - mean_output_loss: 7.5196e-04 - max_output_mean_squared_error: 8.0588e-04 - min_output_mean_squared_error: 0.0010 - mean_output_mean_squared_error: 7.5196e-04 - val_loss: 0.0026 - val_max_output_loss: 5.6765e-04 - val_min_output_loss: 0.0014 - val_mean_output_loss: 4.9259e-04 - val_max_output_mean_squared_error: 5.6765e-04 - val_min_output_mean_squared_error: 0.0014 - val_mean_output_mean_squared_error: 4.9259e-04
# Epoch 38/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 8.1858e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.5462e-04 - max_output_mean_squared_error: 8.1858e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.5462e-04 - val_loss: 0.0029 - val_max_output_loss: 7.2319e-04 - val_min_output_loss: 0.0012 - val_mean_output_loss: 8.0550e-04 - val_max_output_mean_squared_error: 7.2319e-04 - val_min_output_mean_squared_error: 0.0012 - val_mean_output_mean_squared_error: 8.0550e-04
# Epoch 39/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 7.6124e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.5678e-04 - max_output_mean_squared_error: 7.6124e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.5678e-04 - val_loss: 0.0023 - val_max_output_loss: 4.9355e-04 - val_min_output_loss: 0.0010 - val_mean_output_loss: 6.3054e-04 - val_max_output_mean_squared_error: 4.9355e-04 - val_min_output_mean_squared_error: 0.0010 - val_mean_output_mean_squared_error: 6.3054e-04
# Epoch 40/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0027 - max_output_loss: 7.5161e-04 - min_output_loss: 0.0010 - mean_output_loss: 7.0552e-04 - max_output_mean_squared_error: 7.5161e-04 - min_output_mean_squared_error: 0.0010 - mean_output_mean_squared_error: 7.0552e-04 - val_loss: 0.0025 - val_max_output_loss: 4.6165e-04 - val_min_output_loss: 0.0013 - val_mean_output_loss: 5.2662e-04 - val_max_output_mean_squared_error: 4.6165e-04 - val_min_output_mean_squared_error: 0.0013 - val_mean_output_mean_squared_error: 5.2662e-04
# Epoch 41/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0029 - max_output_loss: 7.7666e-04 - min_output_loss: 0.0011 - mean_output_loss: 8.1113e-04 - max_output_mean_squared_error: 7.7666e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 8.1113e-04 - val_loss: 0.0025 - val_max_output_loss: 4.5416e-04 - val_min_output_loss: 0.0012 - val_mean_output_loss: 6.1552e-04 - val_max_output_mean_squared_error: 4.5416e-04 - val_min_output_mean_squared_error: 0.0012 - val_mean_output_mean_squared_error: 6.1552e-04
# Epoch 42/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 7.5141e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.7372e-04 - max_output_mean_squared_error: 7.5141e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.7372e-04 - val_loss: 0.0026 - val_max_output_loss: 4.3992e-04 - val_min_output_loss: 0.0012 - val_mean_output_loss: 8.0554e-04 - val_max_output_mean_squared_error: 4.3992e-04 - val_min_output_mean_squared_error: 0.0012 - val_mean_output_mean_squared_error: 8.0554e-04
# Epoch 43/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 7.9652e-04 - min_output_loss: 0.0010 - mean_output_loss: 7.4696e-04 - max_output_mean_squared_error: 7.9652e-04 - min_output_mean_squared_error: 0.0010 - mean_output_mean_squared_error: 7.4696e-04 - val_loss: 0.0024 - val_max_output_loss: 5.6268e-04 - val_min_output_loss: 0.0011 - val_mean_output_loss: 5.8252e-04 - val_max_output_mean_squared_error: 5.6268e-04 - val_min_output_mean_squared_error: 0.0011 - val_mean_output_mean_squared_error: 5.8252e-04
# Epoch 44/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 8.2835e-04 - min_output_loss: 0.0010 - mean_output_loss: 7.3618e-04 - max_output_mean_squared_error: 8.2835e-04 - min_output_mean_squared_error: 0.0010 - mean_output_mean_squared_error: 7.3618e-04 - val_loss: 0.0030 - val_max_output_loss: 4.9393e-04 - val_min_output_loss: 0.0013 - val_mean_output_loss: 0.0011 - val_max_output_mean_squared_error: 4.9393e-04 - val_min_output_mean_squared_error: 0.0013 - val_mean_output_mean_squared_error: 0.0011
# Epoch 45/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 7.4068e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.5988e-04 - max_output_mean_squared_error: 7.4068e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.5988e-04 - val_loss: 0.0025 - val_max_output_loss: 5.3071e-04 - val_min_output_loss: 0.0013 - val_mean_output_loss: 5.1725e-04 - val_max_output_mean_squared_error: 5.3071e-04 - val_min_output_mean_squared_error: 0.0013 - val_mean_output_mean_squared_error: 5.1725e-04
# Epoch 46/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0027 - max_output_loss: 7.2606e-04 - min_output_loss: 0.0010 - mean_output_loss: 7.2405e-04 - max_output_mean_squared_error: 7.2606e-04 - min_output_mean_squared_error: 0.0010 - mean_output_mean_squared_error: 7.2405e-04 - val_loss: 0.0026 - val_max_output_loss: 4.7494e-04 - val_min_output_loss: 0.0014 - val_mean_output_loss: 5.2957e-04 - val_max_output_mean_squared_error: 4.7494e-04 - val_min_output_mean_squared_error: 0.0014 - val_mean_output_mean_squared_error: 5.2957e-04
# Epoch 47/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 8.0728e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.2934e-04 - max_output_mean_squared_error: 8.0728e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.2934e-04 - val_loss: 0.0022 - val_max_output_loss: 5.4408e-04 - val_min_output_loss: 9.4320e-04 - val_mean_output_loss: 5.2252e-04 - val_max_output_mean_squared_error: 5.4408e-04 - val_min_output_mean_squared_error: 9.4320e-04 - val_mean_output_mean_squared_error: 5.2252e-04
# Epoch 48/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0027 - max_output_loss: 7.7145e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.2784e-04 - max_output_mean_squared_error: 7.7145e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.2784e-04 - val_loss: 0.0026 - val_max_output_loss: 5.7935e-04 - val_min_output_loss: 0.0012 - val_mean_output_loss: 6.7003e-04 - val_max_output_mean_squared_error: 5.7935e-04 - val_min_output_mean_squared_error: 0.0012 - val_mean_output_mean_squared_error: 6.7003e-04
# Epoch 49/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0027 - max_output_loss: 7.5051e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.1387e-04 - max_output_mean_squared_error: 7.5051e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.1387e-04 - val_loss: 0.0024 - val_max_output_loss: 5.2795e-04 - val_min_output_loss: 0.0011 - val_mean_output_loss: 6.0075e-04 - val_max_output_mean_squared_error: 5.2795e-04 - val_min_output_mean_squared_error: 0.0011 - val_mean_output_mean_squared_error: 6.0075e-04
# Epoch 50/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 8.0423e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.2399e-04 - max_output_mean_squared_error: 8.0423e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.2399e-04 - val_loss: 0.0022 - val_max_output_loss: 4.5418e-04 - val_min_output_loss: 9.3582e-04 - val_mean_output_loss: 5.8052e-04 - val_max_output_mean_squared_error: 4.5418e-04 - val_min_output_mean_squared_error: 9.3582e-04 - val_mean_output_mean_squared_error: 5.8052e-04
# Epoch 51/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0027 - max_output_loss: 7.4268e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.3650e-04 - max_output_mean_squared_error: 7.4268e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.3650e-04 - val_loss: 0.0025 - val_max_output_loss: 5.2830e-04 - val_min_output_loss: 0.0011 - val_mean_output_loss: 7.2499e-04 - val_max_output_mean_squared_error: 5.2830e-04 - val_min_output_mean_squared_error: 0.0011 - val_mean_output_mean_squared_error: 7.2499e-04
# Epoch 52/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0027 - max_output_loss: 7.4753e-04 - min_output_loss: 0.0010 - mean_output_loss: 7.1640e-04 - max_output_mean_squared_error: 7.4753e-04 - min_output_mean_squared_error: 0.0010 - mean_output_mean_squared_error: 7.1640e-04 - val_loss: 0.0026 - val_max_output_loss: 5.4188e-04 - val_min_output_loss: 0.0013 - val_mean_output_loss: 6.0241e-04 - val_max_output_mean_squared_error: 5.4188e-04 - val_min_output_mean_squared_error: 0.0013 - val_mean_output_mean_squared_error: 6.0241e-04
# Epoch 53/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 8.0267e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.8141e-04 - max_output_mean_squared_error: 8.0267e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.8141e-04 - val_loss: 0.0024 - val_max_output_loss: 6.1187e-04 - val_min_output_loss: 0.0010 - val_mean_output_loss: 5.5365e-04 - val_max_output_mean_squared_error: 6.1187e-04 - val_min_output_mean_squared_error: 0.0010 - val_mean_output_mean_squared_error: 5.5365e-04
# Epoch 54/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0027 - max_output_loss: 7.6788e-04 - min_output_loss: 0.0010 - mean_output_loss: 7.0354e-04 - max_output_mean_squared_error: 7.6788e-04 - min_output_mean_squared_error: 0.0010 - mean_output_mean_squared_error: 7.0354e-04 - val_loss: 0.0025 - val_max_output_loss: 7.5043e-04 - val_min_output_loss: 0.0010 - val_mean_output_loss: 5.9970e-04 - val_max_output_mean_squared_error: 7.5043e-04 - val_min_output_mean_squared_error: 0.0010 - val_mean_output_mean_squared_error: 5.9970e-04
# Epoch 55/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0028 - max_output_loss: 7.9907e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.2158e-04 - max_output_mean_squared_error: 7.9907e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.2158e-04 - val_loss: 0.0023 - val_max_output_loss: 4.5181e-04 - val_min_output_loss: 0.0011 - val_mean_output_loss: 5.8114e-04 - val_max_output_mean_squared_error: 4.5181e-04 - val_min_output_mean_squared_error: 0.0011 - val_mean_output_mean_squared_error: 5.8114e-04
# Epoch 56/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0027 - max_output_loss: 7.4936e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.0496e-04 - max_output_mean_squared_error: 7.4936e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.0496e-04 - val_loss: 0.0026 - val_max_output_loss: 7.1647e-04 - val_min_output_loss: 0.0011 - val_mean_output_loss: 6.3063e-04 - val_max_output_mean_squared_error: 7.1647e-04 - val_min_output_mean_squared_error: 0.0011 - val_mean_output_mean_squared_error: 6.3063e-04
# Epoch 57/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0027 - max_output_loss: 7.0755e-04 - min_output_loss: 9.9623e-04 - mean_output_loss: 7.8560e-04 - max_output_mean_squared_error: 7.0755e-04 - min_output_mean_squared_error: 9.9623e-04 - mean_output_mean_squared_error: 7.8560e-04 - val_loss: 0.0023 - val_max_output_loss: 4.9367e-04 - val_min_output_loss: 0.0011 - val_mean_output_loss: 5.2472e-04 - val_max_output_mean_squared_error: 4.9367e-04 - val_min_output_mean_squared_error: 0.0011 - val_mean_output_mean_squared_error: 5.2472e-04
# Epoch 58/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0027 - max_output_loss: 7.7053e-04 - min_output_loss: 0.0010 - mean_output_loss: 7.1400e-04 - max_output_mean_squared_error: 7.7053e-04 - min_output_mean_squared_error: 0.0010 - mean_output_mean_squared_error: 7.1400e-04 - val_loss: 0.0023 - val_max_output_loss: 4.6054e-04 - val_min_output_loss: 0.0010 - val_mean_output_loss: 5.9370e-04 - val_max_output_mean_squared_error: 4.6054e-04 - val_min_output_mean_squared_error: 0.0010 - val_mean_output_mean_squared_error: 5.9370e-04
# Epoch 59/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0026 - max_output_loss: 7.6554e-04 - min_output_loss: 9.9468e-04 - mean_output_loss: 7.2622e-04 - max_output_mean_squared_error: 7.6554e-04 - min_output_mean_squared_error: 9.9468e-04 - mean_output_mean_squared_error: 7.2622e-04 - val_loss: 0.0023 - val_max_output_loss: 6.3695e-04 - val_min_output_loss: 9.6185e-04 - val_mean_output_loss: 5.1428e-04 - val_max_output_mean_squared_error: 6.3695e-04 - val_min_output_mean_squared_error: 9.6185e-04 - val_mean_output_mean_squared_error: 5.1428e-04
# Epoch 60/60
# 11725/11725 [==============================] - 17s 1ms/step - loss: 0.0027 - max_output_loss: 7.6033e-04 - min_output_loss: 0.0011 - mean_output_loss: 7.0399e-04 - max_output_mean_squared_error: 7.6033e-04 - min_output_mean_squared_error: 0.0011 - mean_output_mean_squared_error: 7.0399e-04 - val_loss: 0.0025 - val_max_output_loss: 5.8881e-04 - val_min_output_loss: 0.0011 - val_mean_output_loss: 5.6644e-04 - val_max_output_mean_squared_error: 5.8881e-04 - val_min_output_mean_squared_error: 0.0011 - val_mean_output_mean_squared_error: 5.6644e-04

# %%
y1 = log.history['loss']
y2 = log.history['val_loss']
x = np.arange(0, len(y1), 1)
plt.figure()
l, = plt.plot(x, y1)
vl, = plt.plot(x, y2)
plt.title("Complete training loss")
plt.legend([l, vl], ["trian", "valid"])

y1 = log.history['loss'][1:]
y2 = log.history['val_loss'][1:]
x = np.arange(0, len(y1), 1)
plt.figure()
plt.title("Training loss without first epoch")
l, = plt.plot(x, y1)
vl, = plt.plot(x, y2)
plt.legend([l, vl], ["trian", "valid"])

# %% [markdown]
# ### Save the model to file

# %%
# save weight
Indexer.save("indexer")

# %% [markdown]
# ### Load model from saved file

# %%
# load model weight
Indexer = load_model("indexer")

# %%
Indexer.get_weights()
# Out:
# [array([[-3.4520389e-35,  2.9544828e-32, -2.0510670e-05, ...,
#          -1.5298687e-05, -2.8724995e-35,  3.7290208e-04],
#         [ 7.7939032e-34,  3.2703186e-33, -2.4192200e-06, ...,
#          -9.9204481e-06, -1.0031102e-34,  4.1741581e-04],
#         [ 7.0118881e-35,  2.3236103e-32,  1.5542577e-05, ...,
#          -2.3212595e-05,  1.2091309e-34,  3.9817696e-04],
#         [-3.6283378e-35,  1.8816386e-32, -2.9300934e-05, ...,
#          -2.2772474e-05,  4.4185088e-35,  3.4449497e-04]], dtype=float32),
#  array([[-0.02902507,  0.0295391 , -0.01368902, ...,  0.00976387,
#          -0.07330467,  0.09954473],
#         [ 0.09874868,  0.14211053, -0.00061442, ...,  0.04099669,
#          -0.0275308 ,  0.10779361],
#         [ 0.01991568,  0.07881954,  0.02772279, ...,  0.00930407,
#           0.03015326,  0.21875787],
#         ...,
#         -2.96360366e-02,  1.11495487e-01,  3.90501499e-01,  4.09986705e-01],
#        dtype=float32),
#  array([[ 0.13728885,  0.23548834,  0.21219115, ..., -0.13850753,
#           0.18963774,  0.15510973],
#         [-0.22654963,  0.18937929,  0.24562483, ...,  0.03546554,
#          -0.17667489,  0.0022253 ],
#         [-0.0137527 ,  0.0586254 ,  0.31263864, ...,  0.15717311,
#          -0.10993361,  0.1310469 ],
#         ...,
#         [ 0.02137102,  0.37886095,  0.3452559 , ...,  0.21007319,
#           0.11086152,  0.08244887],
#         [ 0.1851017 , -0.18333393, -0.06398284, ...,  0.09503085,
#           0.05427701,  0.02706784],
#         [-0.02323828,  0.6576487 ,  0.5452493 , ...,  0.6047337 ,
#           0.02628502,  0.5708554 ]], dtype=float32),
#  array([-0.04231576, -0.00621222, -0.00874772, -0.00497532, -0.04294487,
#          0.00635579, -0.00775831, -0.03658563, -0.00254138, -0.03002719,
#          0.01981914, -0.04282808,  0.00125641,  0.01202435, -0.03702878,
#         -0.03002719, -0.03251467,  0.00150726, -0.02778705,  0.01488172,
#         -0.02779292, -0.03002633, -0.005028  ,  0.01142699,  0.01297426,
#          0.00081158, -0.03002617,  0.00162837, -0.03002626,  0.00579426,
#          0.01550291, -0.0025255 , -0.01225304,  0.00700268, -0.03002182,
#          0.00633096, -0.03517962, -0.03455192,  0.01552115, -0.12372436,
#          0.01366101, -0.12674466, -0.00468544, -0.06882007, -0.00325121,
#         -0.04163933, -0.03001799, -0.03238648, -0.03002557, -0.04883629,
#          0.00479066, -0.02760064, -0.1517274 ,  0.00211809,  0.00483012,
#          0.0024675 , -0.03002639, -0.00323707, -0.04086044, -0.00050567,
#         -0.03002007, -0.00521246, -0.02819011, -0.00185001], dtype=float32),
#  array([[-0.15853058,  0.11075818, -0.05858025, ...,  0.1251893 ,
#           0.8364499 , -0.69897205],
#         [ 0.08630292,  0.1380707 , -0.03514482, ...,  0.0857259 ,
#           0.03309332, -0.12007862],
#         [-0.0362617 , -0.09313834, -0.14263   , ..., -0.0103729 ,
#           0.08487964, -0.04494017],
#         ...,
#         [-0.17175077, -0.02917904, -0.10772958, ...,  0.10838932,
#           0.13863648,  0.07189562],
#         [-0.1525487 , -0.13892047,  0.11084262, ..., -0.01017059,
#          -0.01471331,  0.23978192],
#         [ 0.08923834, -0.12553748, -0.14523822, ..., -0.05574893,
#           0.0664632 , -0.08865917]], dtype=float32),
#  array([-0.02988075, -0.00985074, -0.02579867, -0.02668984, -0.01139873,
#          0.01033862, -0.00902819,  0.02053909,  0.01883784, -0.04623707,
#          0.        ,  0.01519275,  0.00819312, -0.07713377,  0.02211371,
#          0.01571332, -0.04028025, -0.03002713, -0.0175528 , -0.08898196,
#          0.01898863, -0.01471993, -0.005091  , -0.02993135, -0.03038829,
#          0.0143502 , -0.04082786,  0.01515761, -0.03002523, -0.03002713,
#         -0.02981272, -0.0300267 ,  0.01200575,  0.01268489,  0.01786398,
#         -0.01371836,  0.013064  ,  0.01878055, -0.04518737, -0.03002642,
#         -0.03290972, -0.01096749, -0.03002637,  0.01384434, -0.01821015,
#         -0.03002622, -0.02779314, -0.02657323, -0.03002593, -0.02266118,
#          0.01615233, -0.03002679, -0.02613755,  0.01763502, -0.02392235,
#          0.02020278, -0.1137247 ,  0.02015256, -0.02565395,  0.01524191,
#         -0.03213821, -0.03002333, -0.00460099,  0.01455969], dtype=float32),
#  array([[-0.09280273, -0.36293396, -0.19838509, ...,  0.02966524,
#          -0.00828313,  0.3000483 ],
#         [-0.10474595, -0.04720427, -0.07762916, ..., -0.21425305,
#           0.12723757,  0.09135129],
#         [-0.0431824 , -0.09632108, -0.01107201, ..., -0.15213475,
#          -0.06755371, -0.03429936],
#         ...,
#         [ 0.25872877,  0.30043882, -0.14710222, ...,  0.15672721,
#           0.0912571 , -0.25231022],
#         [ 0.08740868,  0.43245855,  0.1617782 , ..., -0.10976461,
#          -0.01986369, -0.33038172],
#         [ 0.21655671,  0.2444631 ,  0.04351744, ..., -0.09522282,
#           0.11795722, -0.20877063]], dtype=float32),
#  array([-7.3197382e-03, -7.0270044e-03, -3.8677998e-02,  5.8996971e-03,
#          5.5506481e-03, -3.0026471e-02, -3.5539858e-02,  1.4264291e-02,
#         -3.4299530e-02,  5.4777046e-03, -3.8814448e-02,  4.0116571e-03,
#          7.4714068e-03, -3.5302538e-02,  7.2064251e-03, -2.6050553e-02,
#          1.2398978e-02,  7.0032780e-05, -6.7475196e-03,  6.7870962e-03,
#         -4.3515150e-02, -2.5118949e-02,  0.0000000e+00, -8.2066254e-04,
#          7.9161366e-03, -6.0765571e-03,  8.8003082e-03, -3.1164601e-02,
#         -1.3001032e-01, -5.0051860e-03,  4.2064209e-03, -3.8513996e-02,
#         -9.7119123e-02,  4.7198930e-03,  4.7058505e-03,  2.0800314e-03,
#         -3.0027194e-02, -1.2239952e-03, -2.1760175e-03,  5.8754892e-03,
#          1.1129698e-03,  1.0357095e-02, -4.0367708e-02,  8.2563516e-03,
#         -2.7653383e-02, -3.0019553e-02, -3.5557013e-02, -3.0026099e-02,
#         -1.3726270e-01, -6.4819294e-04, -2.7921489e-03,  9.2916498e-03,
#         -2.7737807e-02,  1.6546452e-03, -8.4014458e-04, -4.3792542e-02,
#         -5.8390923e-02, -7.7098049e-03, -4.1645054e-02,  6.8203583e-03,
#          1.2684507e-02, -3.0025557e-02, -3.8574036e-02,  9.7339032e-03],
#        dtype=float32),
#  array([[ 0.2517673 ],
#         [-0.20483558],
#         [-0.20736045],
#         [-0.24752156],
#         [ 0.01307543],
#         [-0.2610527 ],
#         [-0.19108452],
#         [ 0.16327976],
#         [-0.29437828],
#         [-0.16832191],
#         [ 0.3109918 ],
#         [-0.0285744 ],
#         [-0.25146103],
#         [ 0.32815853],
#         [-0.00102673],
#         [-0.23995888],
#         [-0.00594645],
#         [-0.26062348],
#         [ 0.18150607],
#         [ 0.25247934],
#         [-0.02219704],
#         [-0.03061213],
#         [-0.29447827],
#         [ 0.34538892],
#         [ 0.3323347 ],
#         [-0.2641799 ],
#         [ 0.24666226],
#         [-0.24380255],
#         [ 0.20040421],
#         [ 0.26290247],
#         [ 0.29206374],
#         [-0.22203341],
#         [ 0.03964517],
#         [ 0.29630294],
#         [ 0.037407  ],
#         [ 0.25467482],
#         [ 0.02331227],
#         [ 0.00066576],
#         [ 0.29575825],
#         [-0.12252949],
#         [ 0.30681792],
#         [ 0.25956696],
#         [-0.26231983],
#         [ 0.06487271],
#         [-0.2661716 ],
#         [ 0.15967043],
#         [ 0.02190457],
#         [ 0.00292746],
#         [ 0.14302666],
#         [-0.121156  ],
#         [ 0.41077945],
#         [-0.0165427 ],
#         [-0.214487  ],
#         [-0.26724434],
#         [-0.20431039],
#         [ 0.29143906],
#         [ 0.26098856],
#         [-0.22754027],
#         [-0.03196657],
#         [-0.2292689 ],
#         [ 0.05466927],
#         [-0.22896   ],
#         [ 0.01134865],
#         [-0.20903057]], dtype=float32),
#  array([0.07134023], dtype=float32),
#  array([[ 0.01298459],
#         [ 0.12050501],
#         [-0.1626935 ],
#         [ 0.017677  ],
#         [-0.37767887],
#         [ 0.26262698],
#         [-0.3452351 ],
#         [ 0.23436359],
#         [ 0.20922321],
#         [ 0.08790707],
#         [ 0.10495239],
#         [ 0.19994599],
#         [ 0.21507253],
#         [-0.20542529],
#         [ 0.21194945],
#         [ 0.2745045 ],
#         [ 0.25387397],
#         [-0.21421194],
#         [-0.42682624],
#         [-0.25557435],
#         [ 0.20129672],
#         [-0.45561472],
#         [-0.39519957],
#         [ 0.05741904],
#         [-0.08794854],
#         [ 0.20417202],
#         [ 0.11402398],
#         [ 0.2575323 ],
#         [-0.01277613],
#         [-0.25460717],
#         [ 0.22884557],
#         [ 0.20674011],
#         [ 0.23861913],
#         [ 0.24494945],
#         [ 0.18702045],
#         [-0.36663106],
#         [ 0.25371414],
#         [ 0.19341919],
#         [-0.0369201 ],
#         [-0.06435549],
#         [ 0.14935064],
#         [-0.43082106],
#         [-0.07094847],
#         [ 0.25119844],
#         [-0.43224943],
#         [ 0.10860192],
#         [ 0.15155905],
#         [ 0.27105168],
#         [ 0.07935429],
#         [ 0.16317563],
#         [ 0.23585175],
#         [ 0.23093855],
#         [ 0.24497466],
#         [ 0.2102177 ],
#         [-0.33955288],
#         [ 0.16810708],
#         [-0.0356932 ],
#         [ 0.19355482],
#         [ 0.24506935],
#         [ 0.238769  ],
#         [ 0.05011285],
#         [ 0.03268353],
#         [-0.41316804],
#         [ 0.21144085]], dtype=float32),
#  array([0.00549093], dtype=float32),
#  array([[-0.31247178],
#         [-0.2521186 ],
#         [ 0.1997483 ],
#         [-0.2755475 ],
#         [-0.28937802],
#         [ 0.22414139],
#         [-0.02131915],
#         [ 0.2442238 ],
#         [-0.01966165],
#         [ 0.2657385 ],
#         [ 0.01175732],
#         [ 0.24724217],
#         [ 0.27348924],
#         [-0.01674675],
#         [ 0.2748995 ],
#         [ 0.01003932],
#         [ 0.30934694],
#         [-0.21282929],
#         [-0.24821447],
#         [-0.21984097],
#         [ 0.00703291],
#         [-0.13755369],
#         [-0.1461416 ],
#         [-0.28822047],
#         [ 0.3102258 ],
#         [-0.3101198 ],
#         [-0.2476395 ],
#         [ 0.16181634],
#         [ 0.17421806],
#         [-0.2684532 ],
#         [ 0.26520792],
#         [-0.058479  ],
#         [-0.24749637],
#         [ 0.25566941],
#         [ 0.29277363],
#         [-0.27543354],
#         [-0.21280837],
#         [-0.32973886],
#         [-0.31295714],
#         [ 0.26495677],
#         [-0.23787665],
#         [ 0.30912936],
#         [ 0.15895556],
#         [ 0.26730824],
#         [ 0.01197644],
#         [ 0.00551091],
#         [ 0.21365826],
#         [-0.02073175],
#         [ 0.11605699],
#         [-0.28859892],
#         [-0.193869  ],
#         [ 0.32232198],
#         [-0.1592383 ],
#         [-0.289647  ],
#         [-0.31198913],
#         [-0.05359136],
#         [ 0.18949236],
#         [-0.35751972],
#         [-0.17135848],
#         [ 0.30951256],
#         [ 0.3089477 ],
#         [ 0.11776952],
#         [-0.1690094 ],
#         [ 0.3180706 ]], dtype=float32),
#  array([0.04980598], dtype=float32)]

# %% [markdown]
# ### An example of how to use the model to predict time series data

# %%
# example of prediction
input_seq = train_data['train_input'][0].reshape((-1, input_len, 4))
output = Indexer.predict(input_seq)
output
# Out:
# [array([[0.06818587]], dtype=float32),
#  array([[0.05375708]], dtype=float32),
#  array([[0.04973366]], dtype=float32)]

# %% [markdown]
# ### Visualize result

# %%
def compare_output(predicted, correct, title, length=-1):
    if length < 0:
        x = np.arange(0, correct.shape[0] + length)
    else:
        x = np.arange(0, length)
    plt.figure(figsize=(22, 2))
    plt.title(title)
    sample_label, = plt.plot(x, correct[:length], label="sample")
    predict_label, = plt.plot(x, predicted[:length], label="predict")
    plt.legend([sample_label, predict_label], ["sample", "predict"])
    plt.plot()

# %%
length = -1
which = "train"
predicted = Indexer.predict_on_batch([train_data[which+'_input']])
correct = train_data[which+'_output_max']
compare_output(predicted[0], correct, "train"+'_max', length)
correct = train_data[which+'_output_min']
compare_output(predicted[1], correct, "train"+"_min", length)
correct = train_data[which+'_output_mean']
compare_output(predicted[1], correct, "train"+"_mean", length)
which = "test"
predicted = Indexer.predict_on_batch([train_data[which+'_input']])
correct = train_data[which+'_output_max']
compare_output(predicted[0], correct, "valid"+'_max', length)
correct = train_data[which+'_output_min']
compare_output(predicted[1], correct, "valid"+"_min", length)
correct = train_data[which+'_output_mean']
compare_output(predicted[1], correct, "valid"+"_mean", length)
which = "valid"
predicted = Indexer.predict_on_batch([train_data[which+'_input']])
correct = train_data[which+'_output_max']
compare_output(predicted[0], correct, "test"+'_max', length)
correct = train_data[which+'_output_min']
compare_output(predicted[1], correct, "test"+"_min", length)
correct = train_data[which+'_output_mean']
compare_output(predicted[1], correct, "test"+"_mean", length)

# %%
length = -1

for which in ["train", "test", "valid"]:
    predicted = Indexer.predict_on_batch([train_data[which+'_input']])
    correct = train_data[which+'_output_max']
    compare_output(predicted[0], correct, which+'_max', length)
    correct = train_data[which+'_output_min']
    compare_output(predicted[1], correct, which+"_min", length)
    correct = train_data[which+'_output_mean']
    compare_output(predicted[1], correct, which+"_mean", length)
