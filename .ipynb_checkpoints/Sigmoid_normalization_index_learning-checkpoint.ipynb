# %% [markdown]
# ## This is an algorithm development playground for UBS Quant contest

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential, Model, load_model
from keras.layers import Dense
from keras.layers import LSTM, GRU, Conv1D, MaxPooling1D, Flatten, TimeDistributed, Concatenate
from keras.layers import GaussianNoise, BatchNormalization, Dropout
from keras.layers import Activation, merge, Input, concatenate, Reshape, add
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.callbacks import Callback, LambdaCallback, TensorBoard, ReduceLROnPlateau, EarlyStopping, LearningRateScheduler
from keras.utils import np_utils, to_categorical
from keras.utils.vis_utils import plot_model 
import tensorflow as tf
import keras.backend as K
import matplotlib.pyplot as plt
import time
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
def get_update_rate(df, n=5):
    update_rate = []
    for i in range(len(df.columns)):
        counter_start = 0
        min_counter = len(df) + 1
        for j in range(n): # go for n loops to verify the update rate
            counter = 0
            start = df.iloc[counter_start, i]
            while True:
                counter += 1
                if not start == df.iloc[counter_start+counter, i]:
                    break
            counter_start = counter + counter_start
            if counter < min_counter:
                min_counter = counter
            if counter_start >= len(df):
                break
        update_rate.append(min_counter)
    return update_rate

# %%
def windowed_return_rate(df, window_size=14, thresh=0.005):
    """
    use the mean of this window_size, and previous window_size to calcualte a stablized return rate
    
    the start_index is window_size
    """
    out = df.copy()
    
    counter = window_size
    for i in range(window_size, len(df)-window_size):
        prev_mean = df.iloc[i-window_size:i, :].mean()
        cur_mean = df.iloc[i:i+window_size, :].mean()
        cur_row = (cur_mean - prev_mean) / prev_mean
        
        if not (cur_row <= 2).all() or not (cur_row > -0.8).all(): # use the most recent good row as cur row, if bad data
            cur_row = good_row
        else: # update good row if not bad data
            good_row = cur_row
            
        # updata data
        out.iloc[counter, :] = cur_row
        
        # updata counter
        counter += 1
        
    # discretize data
    out[out > thresh] = 2
    out[abs(out) <= thresh] = 1
    out[out < -thresh] = 0
    
    return out.iloc[window_size:counter, :]

def moving_average(df, window_size=5):
    """
    Do move average on window_size
    """
    out = df.copy()
    
    # do window_size moving average
    for i in range(window_size, len(df)+1):
        out.iloc[i-1, :] = df.iloc[i-window_size:i, :].mean()
    
    return out.iloc[window_size-1:, :]

def sigmoid_normalize(df, decimal_move=3, positive_input=True):
    """
    Move the decimal to the right by decimal_move,
    then use sigmoid to normalize the data to 0-0.5
    """
    # defining sigmoid function
    def sigmoid(x):
        if not positive_input:
            return 1 / (1 + np.exp(-x))
        else:
            return 2 * (1 / (1 + np.exp(-x)) - 0.5)
    
    # do sigmoid normalizing + decimal moving
    if type(decimal_move) is int:
        df = (df.copy() / np.power(10, decimal_move)).apply(np.vectorize(sigmoid))
    elif type(decimal_move) is str and decimal_move == "auto":
        # for negative driven data, my processing is slightly clumsy
        auto_decimal_move = df.min().apply(abs).apply(np.log10).astype(int).apply(lambda x: x+1)
        df = (df.copy() / np.power(10, auto_decimal_move)).apply(np.vectorize(sigmoid))
    else:
        df = df.copy().apply(vectorize(sigmoid))
    
    return df

# %%
# read the factor time data
df = pd.read_csv("Dataset_1003.csv", index_col=[0], parse_dates=[0])

# seperate S&P label out
target = df.iloc[:, :4]
tmp = df.iloc[:, 4:]

# collect col index for daily updated factors and quarterly updated factors
rate = get_update_rate(tmp)
slow_index = [i for i, r in enumerate(rate) if r > 1 and i not in [tmp.columns.get_loc('Change in private inventories')]]
quick_index = [i for i, r in enumerate(rate) if r == 1 and i not in [tmp.columns.get_loc("__SIC1_D_High")]]

# seperate slowly updated factor and quickly updated factor
slow_df = tmp.iloc[:, slow_index]
quick_df = tmp.iloc[:, quick_index]

# do moving average on quickly updated data
quick_df = moving_average(quick_df, window_size=5)
target = moving_average(target, window_size=5)

# normalize target
target = sigmoid_normalize(target, decimal_move=3, positive_input=True)

# normalize fast updated factor
quick_df = sigmoid_normalize(quick_df, decimal_move='auto', positive_input=True)

# normalize slowly updated factor
slow_df = sigmoid_normalize(slow_df, decimal_move='auto', positive_input=False)

# process label
label= windowed_return_rate(target, window_size=10)

# align data
index_seq = list(target.columns) + list(slow_df.columns) + list(quick_df.columns) + list(label.columns)
tmp = pd.concat([target, slow_df, quick_df, label], axis=1, join="inner")
tmp = tmp.reindex(columns=index_seq)
target = tmp.iloc[:, :len(target.columns)]
slow_df = tmp.iloc[:, len(target.columns):len(slow_df.columns)+len(target.columns)]
quick_df = tmp.iloc[:, len(slow_df.columns)+len(target.columns):-len(label.columns)]
label = tmp.iloc[:, -len(label.columns):]

# %%
# data generator for training and validation of stateless lstm
def generate_train_data(df, label, test_split=0.2, valid_split=0.1, seq_len=365):
    # prepare output
    out = {}
    
    # print out data information
    for i in df:
        print(len(i.columns), end=", ")
    print()
    for i in df:
        print(len(i), end=", ")
    
    # get shortest data length (assuming all data start at the same time)
    data_len = len(df[0])-seq_len
    test_split_len = int(data_len*(1-test_split-valid_split))
    valid_split_len = int(data_len*(1-valid_split))
    
    # create feature sequence
    for i in range(len(df)):
        df[i] = np.array([np.array(df[i].iloc[j:j+seq_len, :]) for j in range(data_len)])
        out["train_df" + str(i)] = df[i][:test_split_len]
        out["test_df" + str(i)] = df[i][test_split_len:valid_split_len]
        out["valid_df" + str(i)] = df[i][valid_split_len:]
    
    # create label sequence
    label = np.array([np.array(label.iloc[i+seq_len, :]) for i in range(data_len)]) # watch out for the shift here
    
    # convert label to categorical format
    label = label.T
    for i in range(4):
        new_label = to_categorical(label[i], num_classes=3)
        out["train_label"+str(i)] = new_label[:test_split_len]
        out["test_label"+str(i)] = new_label[test_split_len:valid_split_len]
        out["valid_label"+str(i)] = new_label[valid_split_len:]
        
    return out

# %%
# generate data
seq_len = 100
train_data = generate_train_data([slow_df, quick_df, target], 
                                 label, seq_len=seq_len, test_split=0.2, valid_split=0.1)
# Out:
# 25, 18, 4,
# 4504, 4504, 4504,

# %%
for i in range(len(label.columns)):
    if i ==0:
        a = label.iloc[:, i].value_counts()
    else:
        a += label.iloc[:, i].value_counts()
count = 1 / a.values
count / np.linalg.norm(count, ord=1)
# Out:
# array([ 0.23920672,  0.36653235,  0.39426093])

# %%
# flow for prev_label_input
prev_target_input = Input(shape=(seq_len, 4))
x = LSTM(units=64, dropout=0.2, activation="relu", kernel_regularizer=l2(l=0.05), return_sequences=False)(prev_target_input)
x = Dense(units=128, activation="relu")(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
output1 = Dense(units=3, activation="softmax")(x)
output2 = Dense(units=3, activation="softmax")(x)
output3 = Dense(units=3, activation="softmax")(x)
output4 = Dense(units=3, activation="softmax")(x)

# compile model
Indexer = Model(inputs=[prev_target_input], outputs=[output1, output2, output3, output4])
Indexer.compile(loss="categorical_crossentropy", optimizer=Adam(lr=0.0001), metrics=["categorical_crossentropy"])

# display model
plot_model(model=Indexer, to_file="temp.png")
Indexer.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 100, 4)       0
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 64)           17664       input_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          8320        lstm_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128)          512         dense_6[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 3)            387         dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 3)            387         dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 3)            387         dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 3)            387         dropout_2[0][0]
# ==================================================================================================
# Total params: 28,044
# Trainable params: 27,788
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %%
valid_output = [train_data['test_label0'], train_data['test_label1'], train_data['test_label2'], train_data['test_label3']]
train_output = [train_data['train_label0'], train_data['train_label1'], train_data['train_label2'], train_data['train_label3']]

Indexer.fit(x=train_data["train_df2"], y=train_output, 
            validation_data=[train_data["test_df2"], valid_output],
            epochs=300, batch_size=64, shuffle=True, verbose=1)
# Out:
# Train on 3082 samples, validate on 881 samples
# Epoch 1/300
# 3082/3082 [==============================] - 6s 2ms/step - loss: 5.4964 - dense_7_loss: 1.2421 - dense_8_loss: 1.3070 - dense_9_loss: 1.2576 - dense_10_loss: 1.3115 - dense_7_categorical_crossentropy: 1.2421 - dense_8_categorical_crossentropy: 1.3070 - dense_9_categorical_crossentropy: 1.2576 - dense_10_categorical_crossentropy: 1.3115 - val_loss: 4.7526 - val_dense_7_loss: 1.0983 - val_dense_8_loss: 1.0861 - val_dense_9_loss: 1.0956 - val_dense_10_loss: 1.1057 - val_dense_7_categorical_crossentropy: 1.0983 - val_dense_8_categorical_crossentropy: 1.0861 - val_dense_9_categorical_crossentropy: 1.0956 - val_dense_10_categorical_crossentropy: 1.1057
# Epoch 2/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 5.1422 - dense_7_loss: 1.1819 - dense_8_loss: 1.2174 - dense_9_loss: 1.1880 - dense_10_loss: 1.1982 - dense_7_categorical_crossentropy: 1.1819 - dense_8_categorical_crossentropy: 1.2174 - dense_9_categorical_crossentropy: 1.1880 - dense_10_categorical_crossentropy: 1.1982 - val_loss: 4.7355 - val_dense_7_loss: 1.0970 - val_dense_8_loss: 1.0942 - val_dense_9_loss: 1.0974 - val_dense_10_loss: 1.1010 - val_dense_7_categorical_crossentropy: 1.0970 - val_dense_8_categorical_crossentropy: 1.0942 - val_dense_9_categorical_crossentropy: 1.0974 - val_dense_10_categorical_crossentropy: 1.1010
# Epoch 3/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.9516 - dense_7_loss: 1.1397 - dense_8_loss: 1.1635 - dense_9_loss: 1.1531 - dense_10_loss: 1.1590 - dense_7_categorical_crossentropy: 1.1397 - dense_8_categorical_crossentropy: 1.1635 - dense_9_categorical_crossentropy: 1.1531 - dense_10_categorical_crossentropy: 1.1590 - val_loss: 4.7214 - val_dense_7_loss: 1.0979 - val_dense_8_loss: 1.0998 - val_dense_9_loss: 1.0979 - val_dense_10_loss: 1.0997 - val_dense_7_categorical_crossentropy: 1.0979 - val_dense_8_categorical_crossentropy: 1.0998 - val_dense_9_categorical_crossentropy: 1.0979 - val_dense_10_categorical_crossentropy: 1.0997
# Epoch 4/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.8768 - dense_7_loss: 1.1430 - dense_8_loss: 1.1493 - dense_9_loss: 1.1313 - dense_10_loss: 1.1362 - dense_7_categorical_crossentropy: 1.1430 - dense_8_categorical_crossentropy: 1.1493 - dense_9_categorical_crossentropy: 1.1313 - dense_10_categorical_crossentropy: 1.1362 - val_loss: 4.7052 - val_dense_7_loss: 1.0982 - val_dense_8_loss: 1.1014 - val_dense_9_loss: 1.0986 - val_dense_10_loss: 1.0995 - val_dense_7_categorical_crossentropy: 1.0982 - val_dense_8_categorical_crossentropy: 1.1014 - val_dense_9_categorical_crossentropy: 1.0986 - val_dense_10_categorical_crossentropy: 1.0995
# Epoch 5/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.7893 - dense_7_loss: 1.1151 - dense_8_loss: 1.1267 - dense_9_loss: 1.1222 - dense_10_loss: 1.1263 - dense_7_categorical_crossentropy: 1.1151 - dense_8_categorical_crossentropy: 1.1267 - dense_9_categorical_crossentropy: 1.1222 - dense_10_categorical_crossentropy: 1.1263 - val_loss: 4.6944 - val_dense_7_loss: 1.1004 - val_dense_8_loss: 1.1034 - val_dense_9_loss: 1.0991 - val_dense_10_loss: 1.1014 - val_dense_7_categorical_crossentropy: 1.1004 - val_dense_8_categorical_crossentropy: 1.1034 - val_dense_9_categorical_crossentropy: 1.0991 - val_dense_10_categorical_crossentropy: 1.1014
# Epoch 6/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.7319 - dense_7_loss: 1.0969 - dense_8_loss: 1.1205 - dense_9_loss: 1.1145 - dense_10_loss: 1.1179 - dense_7_categorical_crossentropy: 1.0969 - dense_8_categorical_crossentropy: 1.1205 - dense_9_categorical_crossentropy: 1.1145 - dense_10_categorical_crossentropy: 1.1179 - val_loss: 4.6803 - val_dense_7_loss: 1.1007 - val_dense_8_loss: 1.1052 - val_dense_9_loss: 1.1014 - val_dense_10_loss: 1.0993 - val_dense_7_categorical_crossentropy: 1.1007 - val_dense_8_categorical_crossentropy: 1.1052 - val_dense_9_categorical_crossentropy: 1.1014 - val_dense_10_categorical_crossentropy: 1.0993
# Epoch 7/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.6633 - dense_7_loss: 1.0939 - dense_8_loss: 1.1036 - dense_9_loss: 1.0947 - dense_10_loss: 1.1047 - dense_7_categorical_crossentropy: 1.0939 - dense_8_categorical_crossentropy: 1.1036 - dense_9_categorical_crossentropy: 1.0947 - dense_10_categorical_crossentropy: 1.1047 - val_loss: 4.6784 - val_dense_7_loss: 1.1058 - val_dense_8_loss: 1.1070 - val_dense_9_loss: 1.1049 - val_dense_10_loss: 1.1021 - val_dense_7_categorical_crossentropy: 1.1058 - val_dense_8_categorical_crossentropy: 1.1070 - val_dense_9_categorical_crossentropy: 1.1049 - val_dense_10_categorical_crossentropy: 1.1021
# Epoch 8/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.5965 - dense_7_loss: 1.0827 - dense_8_loss: 1.0889 - dense_9_loss: 1.0818 - dense_10_loss: 1.0915 - dense_7_categorical_crossentropy: 1.0827 - dense_8_categorical_crossentropy: 1.0889 - dense_9_categorical_crossentropy: 1.0818 - dense_10_categorical_crossentropy: 1.0915 - val_loss: 4.6720 - val_dense_7_loss: 1.1071 - val_dense_8_loss: 1.1086 - val_dense_9_loss: 1.1061 - val_dense_10_loss: 1.1060 - val_dense_7_categorical_crossentropy: 1.1071 - val_dense_8_categorical_crossentropy: 1.1086 - val_dense_9_categorical_crossentropy: 1.1061 - val_dense_10_categorical_crossentropy: 1.1060
# Epoch 9/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.5475 - dense_7_loss: 1.0740 - dense_8_loss: 1.0796 - dense_9_loss: 1.0759 - dense_10_loss: 1.0803 - dense_7_categorical_crossentropy: 1.0740 - dense_8_categorical_crossentropy: 1.0796 - dense_9_categorical_crossentropy: 1.0759 - dense_10_categorical_crossentropy: 1.0803 - val_loss: 4.6715 - val_dense_7_loss: 1.1116 - val_dense_8_loss: 1.1123 - val_dense_9_loss: 1.1060 - val_dense_10_loss: 1.1107 - val_dense_7_categorical_crossentropy: 1.1116 - val_dense_8_categorical_crossentropy: 1.1123 - val_dense_9_categorical_crossentropy: 1.1060 - val_dense_10_categorical_crossentropy: 1.1107
# Epoch 10/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.5146 - dense_7_loss: 1.0694 - dense_8_loss: 1.0785 - dense_9_loss: 1.0677 - dense_10_loss: 1.0741 - dense_7_categorical_crossentropy: 1.0694 - dense_8_categorical_crossentropy: 1.0785 - dense_9_categorical_crossentropy: 1.0677 - dense_10_categorical_crossentropy: 1.0741 - val_loss: 4.6806 - val_dense_7_loss: 1.1160 - val_dense_8_loss: 1.1174 - val_dense_9_loss: 1.1117 - val_dense_10_loss: 1.1169 - val_dense_7_categorical_crossentropy: 1.1160 - val_dense_8_categorical_crossentropy: 1.1174 - val_dense_9_categorical_crossentropy: 1.1117 - val_dense_10_categorical_crossentropy: 1.1169
# Epoch 11/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.4587 - dense_7_loss: 1.0587 - dense_8_loss: 1.0713 - dense_9_loss: 1.0552 - dense_10_loss: 1.0606 - dense_7_categorical_crossentropy: 1.0587 - dense_8_categorical_crossentropy: 1.0713 - dense_9_categorical_crossentropy: 1.0552 - dense_10_categorical_crossentropy: 1.0606 - val_loss: 4.6522 - val_dense_7_loss: 1.1139 - val_dense_8_loss: 1.1130 - val_dense_9_loss: 1.1105 - val_dense_10_loss: 1.1080 - val_dense_7_categorical_crossentropy: 1.1139 - val_dense_8_categorical_crossentropy: 1.1130 - val_dense_9_categorical_crossentropy: 1.1105 - val_dense_10_categorical_crossentropy: 1.1080
# Epoch 12/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.4342 - dense_7_loss: 1.0504 - dense_8_loss: 1.0590 - dense_9_loss: 1.0556 - dense_10_loss: 1.0675 - dense_7_categorical_crossentropy: 1.0504 - dense_8_categorical_crossentropy: 1.0590 - dense_9_categorical_crossentropy: 1.0556 - dense_10_categorical_crossentropy: 1.0675 - val_loss: 4.6555 - val_dense_7_loss: 1.1199 - val_dense_8_loss: 1.1095 - val_dense_9_loss: 1.1121 - val_dense_10_loss: 1.1180 - val_dense_7_categorical_crossentropy: 1.1199 - val_dense_8_categorical_crossentropy: 1.1095 - val_dense_9_categorical_crossentropy: 1.1121 - val_dense_10_categorical_crossentropy: 1.1180
# Epoch 13/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.4125 - dense_7_loss: 1.0490 - dense_8_loss: 1.0601 - dense_9_loss: 1.0504 - dense_10_loss: 1.0619 - dense_7_categorical_crossentropy: 1.0490 - dense_8_categorical_crossentropy: 1.0601 - dense_9_categorical_crossentropy: 1.0504 - dense_10_categorical_crossentropy: 1.0619 - val_loss: 4.6428 - val_dense_7_loss: 1.1168 - val_dense_8_loss: 1.1077 - val_dense_9_loss: 1.1160 - val_dense_10_loss: 1.1163 - val_dense_7_categorical_crossentropy: 1.1168 - val_dense_8_categorical_crossentropy: 1.1077 - val_dense_9_categorical_crossentropy: 1.1160 - val_dense_10_categorical_crossentropy: 1.1163
# Epoch 14/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.3851 - dense_7_loss: 1.0491 - dense_8_loss: 1.0581 - dense_9_loss: 1.0391 - dense_10_loss: 1.0574 - dense_7_categorical_crossentropy: 1.0491 - dense_8_categorical_crossentropy: 1.0581 - dense_9_categorical_crossentropy: 1.0391 - dense_10_categorical_crossentropy: 1.0574 - val_loss: 4.6324 - val_dense_7_loss: 1.1196 - val_dense_8_loss: 1.1105 - val_dense_9_loss: 1.1118 - val_dense_10_loss: 1.1141 - val_dense_7_categorical_crossentropy: 1.1196 - val_dense_8_categorical_crossentropy: 1.1105 - val_dense_9_categorical_crossentropy: 1.1118 - val_dense_10_categorical_crossentropy: 1.1141
# Epoch 15/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.3856 - dense_7_loss: 1.0518 - dense_8_loss: 1.0594 - dense_9_loss: 1.0495 - dense_10_loss: 1.0527 - dense_7_categorical_crossentropy: 1.0518 - dense_8_categorical_crossentropy: 1.0594 - dense_9_categorical_crossentropy: 1.0495 - dense_10_categorical_crossentropy: 1.0527 - val_loss: 4.6614 - val_dense_7_loss: 1.1221 - val_dense_8_loss: 1.1218 - val_dense_9_loss: 1.1219 - val_dense_10_loss: 1.1281 - val_dense_7_categorical_crossentropy: 1.1221 - val_dense_8_categorical_crossentropy: 1.1218 - val_dense_9_categorical_crossentropy: 1.1219 - val_dense_10_categorical_crossentropy: 1.1281
# Epoch 16/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.3526 - dense_7_loss: 1.0460 - dense_8_loss: 1.0519 - dense_9_loss: 1.0414 - dense_10_loss: 1.0498 - dense_7_categorical_crossentropy: 1.0460 - dense_8_categorical_crossentropy: 1.0519 - dense_9_categorical_crossentropy: 1.0414 - dense_10_categorical_crossentropy: 1.0498 - val_loss: 4.6121 - val_dense_7_loss: 1.1177 - val_dense_8_loss: 1.1104 - val_dense_9_loss: 1.1166 - val_dense_10_loss: 1.1080 - val_dense_7_categorical_crossentropy: 1.1177 - val_dense_8_categorical_crossentropy: 1.1104 - val_dense_9_categorical_crossentropy: 1.1166 - val_dense_10_categorical_crossentropy: 1.1080
# Epoch 17/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.3462 - dense_7_loss: 1.0470 - dense_8_loss: 1.0525 - dense_9_loss: 1.0396 - dense_10_loss: 1.0515 - dense_7_categorical_crossentropy: 1.0470 - dense_8_categorical_crossentropy: 1.0525 - dense_9_categorical_crossentropy: 1.0396 - dense_10_categorical_crossentropy: 1.0515 - val_loss: 4.6491 - val_dense_7_loss: 1.1253 - val_dense_8_loss: 1.1179 - val_dense_9_loss: 1.1222 - val_dense_10_loss: 1.1319 - val_dense_7_categorical_crossentropy: 1.1253 - val_dense_8_categorical_crossentropy: 1.1179 - val_dense_9_categorical_crossentropy: 1.1222 - val_dense_10_categorical_crossentropy: 1.1319
# Epoch 18/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.3367 - dense_7_loss: 1.0480 - dense_8_loss: 1.0511 - dense_9_loss: 1.0385 - dense_10_loss: 1.0509 - dense_7_categorical_crossentropy: 1.0480 - dense_8_categorical_crossentropy: 1.0511 - dense_9_categorical_crossentropy: 1.0385 - dense_10_categorical_crossentropy: 1.0509 - val_loss: 4.6878 - val_dense_7_loss: 1.1396 - val_dense_8_loss: 1.1269 - val_dense_9_loss: 1.1347 - val_dense_10_loss: 1.1420 - val_dense_7_categorical_crossentropy: 1.1396 - val_dense_8_categorical_crossentropy: 1.1269 - val_dense_9_categorical_crossentropy: 1.1347 - val_dense_10_categorical_crossentropy: 1.1420
# Epoch 19/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.3114 - dense_7_loss: 1.0417 - dense_8_loss: 1.0468 - dense_9_loss: 1.0360 - dense_10_loss: 1.0456 - dense_7_categorical_crossentropy: 1.0417 - dense_8_categorical_crossentropy: 1.0468 - dense_9_categorical_crossentropy: 1.0360 - dense_10_categorical_crossentropy: 1.0456 - val_loss: 4.6756 - val_dense_7_loss: 1.1304 - val_dense_8_loss: 1.1281 - val_dense_9_loss: 1.1497 - val_dense_10_loss: 1.1294 - val_dense_7_categorical_crossentropy: 1.1304 - val_dense_8_categorical_crossentropy: 1.1281 - val_dense_9_categorical_crossentropy: 1.1497 - val_dense_10_categorical_crossentropy: 1.1294
# Epoch 20/300
# 3082/3082 [==============================] - 5s 2ms/step - loss: 4.2969 - dense_7_loss: 1.0412 - dense_8_loss: 1.0457 - dense_9_loss: 1.0323 - dense_10_loss: 1.0427 - dense_7_categorical_crossentropy: 1.0412 - dense_8_categorical_crossentropy: 1.0457 - dense_9_categorical_crossentropy: 1.0323 - dense_10_categorical_crossentropy: 1.0427 - val_loss: 4.7038 - val_dense_7_loss: 1.1478 - val_dense_8_loss: 1.1331 - val_dense_9_loss: 1.1500 - val_dense_10_loss: 1.1412 - val_dense_7_categorical_crossentropy: 1.1478 - val_dense_8_categorical_crossentropy: 1.1331 - val_dense_9_categorical_crossentropy: 1.1500 - val_dense_10_categorical_crossentropy: 1.1412
# Epoch 21/300
# 2752/3082 [=========================>....] - ETA: 0s - loss: 4.2911 - dense_7_loss: 1.0415 - dense_8_loss: 1.0458 - dense_9_loss: 1.0325 - dense_10_loss: 1.0420 - dense_7_categorical_crossentropy: 1.0415 - dense_8_categorical_crossentropy: 1.0458 - dense_9_categorical_crossentropy: 1.0325 - dense_10_categorical_crossentropy: 1.0420
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-eb56a70195cb> in <module>()
#       4 Indexer.fit(x=train_data["train_df2"], y=train_output,
#       5             validation_data=[train_data["test_df2"], valid_output],
# ----> 6             epochs=300, batch_size=64, shuffle=True, verbose=1)
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1655                               initial_epoch=initial_epoch,
#    1656                               steps_per_epoch=steps_per_epoch,
# -> 1657                               validation_steps=validation_steps)
#    1658
#    1659     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1211                     batch_logs['size'] = len(batch_ids)
#    1212                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1213                     outs = f(ins_batch)
#    1214                     if not isinstance(outs, list):
#    1215                         outs = [outs]
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2355         session = get_session()
#    2356         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2357                               **self.session_kwargs)
#    2358         return updated[:len(self.outputs)]
#    2359
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Currently the system is overfitting to the average
# ### The following methods are to be attempted
# 1. Try to remove corelated input features
# 2. Simplify the current network in a proper way

# %%
def to_discrete(prob):
    prob = prob.copy()
    for i in range(prob.shape[0]):
        arg = prob[i, :].argmax()
        prob[i, :] = np.zeros(3)
        prob[i, arg] = 1
    return prob

def to_class(cate):
    tmp = np.array([-1, 0, 1]).reshape((3, 1))
    return cate.dot(tmp).T.reshape((-1))

def compare_output(predicted, correct):
    correct = to_class(correct)
    predicted = to_class(to_discrete(predicted))
    x = np.arange(0, correct.shape[0])
    plt.figure(figsize=(22, 2))
    plt.plot(x, correct)
    plt.plot(x, predicted)

# %%
for i in range(4):
    which = "train"
    which_output = i
    predicted = Indexer.predict_on_batch([train_data[which+'_df2']])
    predicted = predicted[which_output]
    correct = train_data[which+"_label"+str(which_output)]
    compare_output(predicted, correct)

# %%
# dumped functions


def min_max_average(df, window_size=600):
    """
    use the min and max of the window_size days of data in df to normalize the window_size data.
    this method is running the risk of incorporating future data to the past, but we will see
    
    return the processed df and the start index
    """
    df = df.copy()
    
    for i in range(0, len(df), window_size):
        # find local min max
        dmax = df.iloc[i:i+window_size, :].max()
        dmin = df.iloc[i:i+window_size, :].min()
        
        # normalize data
        df.iloc[i:i+window_size, :] -= dmin
        df.iloc[i:i+window_size, :] /= dmax - dmin
        
    if len(df)%window_size >= window_size / 2:
        # deal with residuals
        # find local min max
        dmax = df.iloc[i-window_size:, :].max()
        dmin = df.iloc[i-window_size:, :].min()

        # normalize data
        df.iloc[i-window_size, :] -= dmin
        df.iloc[i-window_size, :] /= dmax - dmin
        
        return df, 0
    
    return df.iloc[:-(len(df)%window_size), :], 0

# %% [markdown]
# ### Sigmoid normalization research

# %%
# read the factor time data
df = pd.read_csv("Dataset_1003.csv", index_col=[0])

# seperate S&P label out
target = df.iloc[:, :4]
df = df.iloc[:, 4:] # preserve them as the input data

# collect col index for daily updated factors and quarterly updated factors
rate = get_update_rate(df)
slow_index = [i for i, r in enumerate(rate) if r > 1 and i not in [df.columns.get_loc('Change in private inventories')]]
quick_index = [i for i, r in enumerate(rate) if r == 1 and i not in [df.columns.get_loc("__SIC1_D_High")]]

slow_df = df.iloc[:, slow_update_index]

# %%
df.iloc[:, :4].plot()
target.plot()
